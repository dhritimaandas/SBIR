# %%
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
actual_images_dir='/content/gdrive/My Drive/Splitted_SBIR_Data/Images/Training'
target_dir_training='/content/gdrive/My Drive/Splitted_SBIR_Data/Images_Balanced/Training'
target_dir_validation='/content/gdrive/My Drive/Splitted_SBIR_Data/Images_Balanced/Validation'

# %%
tr_or_val=os.listdir(actual_images_dir)

# %%
tr_or_val
#for i in tr_or_val:
#  label_path=
# Out:
# ['alarm clock',
#  'arm',
#  'banana',
#  'barn',
#  'baseball bat',
#  'axe',
#  'armchair',
#  'basket',
#  'ashtray',
#  'backpack',
#  'beer-mug',
#  'book',
#  'binoculars',
#  'cake',
#  'bread',
#  'brain',
#  'bulldozer',
#  'bridge',
#  'camera',
#  'bush',
#  'candle',
#  'cannon',
#  'church',
#  'cow',
#  'crab',
#  'chandelier',
#  'cloud',
#  'castle',
#  'computer monitor',
#  'computer-mouse',
#  'crocodile',
#  'door',
#  'donut',
#  'hedgehog',
#  'eyeglasses',
#  'envelope',
#  'floor lamp',
#  'dolphin',
#  'fish',
#  'giraffe',
#  'helicopter',
#  'hot air balloon',
#  'hot-dog',
#  'hourglass',
#  'loudspeaker',
#  'key',
#  'house',
#  'ipod',
#  'ice-cream-cone',
#  'kangaroo',
#  'lighter',
#  'mailbox',
#  'pear',
#  'megaphone',
#  'pigeon',
#  'parking meter',
#  'microscope',
#  'motorbike',
#  'mosquito',
#  'pen',
#  'parrot',
#  'pumpkin',
#  'race car',
#  'sea turtle',
#  'revolver',
#  'radio',
#  'scissors',
#  'rollerblades',
#  'tractor',
# ...

# %%
import cv2
for label in tr_or_val:
  labels_path=os.path.join(actual_images_dir,label)
  image_names=os.listdir(labels_path)
  #print(image_names,labels_path)
  #break
  os.mkdir(os.path.join('/content/gdrive/My Drive/Splitted_SBIR_Data/Images_Balanced/Training',label))
  #os.mkdir(os.path.join(target_dir_validation,label))
  split1=image_names[:64]
  split2=image_names[64:72]
  for i in split1:
    img_path=os.path.join(labels_path,i)
    temp=cv2.imread(img_path)
    cv2.imwrite(os.path.join(target_dir_training,label,i),temp)

# %%
#import cv2
for label in tr_or_val:
  #labels_path=os.path.join(actual_images_dir,label)
  #image_names=os.listdir(labels_path)
  #print(image_names,labels_path)
  #break
  #os.mkdir(os.path.join('/content/gdrive/My Drive/Splitted_SBIR_Data/Images_Balanced/Training',label))
  os.mkdir(os.path.join('/content/gdrive/My Drive/Splitted_SBIR_Data/Images_Balanced/Validation',label))
  #split1=image_names[:64]
  #split2=image_names[64:72]
  for i in split2:
      img_path=os.path.join(labels_path,i)
      temp=cv2.imread(img_path)
      cv2.imwrite(os.path.join(target_dir_validation,label,i),temp)
